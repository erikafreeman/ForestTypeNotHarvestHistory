# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from treeinterpreter import treeinterpreter as ti, utils
from sklearn.metrics import r2_score
import mitosheet
from rfpimp import *
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

PC7c = pd.read_csv("/home/erika/Downloads/FT_EEMs_2020_PC6_new_20221121-115618_rhoThresh=0.4_pThresh=1e-05_counts - FT_EEMs_2020_PC6_new_20221121-115618_rhoThresh=0.4_pThresh=1e-05_counts (1).csv")
onlyHarv = pd.read_csv("/home/erika/Desktop/Chapter3/Figure4/OnlyinHarvestAfter.csv")

# %%
Hlist = list(onlyHarv['formula_isotopefree'])
comps = ['Comp.1', 'Comp.2','Comp.3','Comp.4','Comp.5','Comp.6']
newlist = ['ICBM_Code']+ Hlist + comps 

print(len(newlist))
# Out:
# 1042

# %%
forms = pd.read_csv("/home/erika/Downloads/InputData/FT_EEMs_2020_PC6_new_20221121-115618.csv")

subset = forms[newlist]
subset.to_csv("/home/erika/Downloads/InputData/FT_EEMs_2020_PC6_harvest_20221121-115618.csv")
# Out:
# /tmp/ipykernel_4604/1098573166.py:1: DtypeWarning: Columns (7449) have mixed types. Specify dtype option on import or set low_memory=False.
#   forms = pd.read_csv("/home/erika/Downloads/InputData/FT_EEMs_2020_PC6_new_20221121-115618.csv")

# %%
PC7c_sum = PC7c.set_index('Unnamed: 0').T

# %%
Comp = 'Comp.6'
display(PC7c_sum)
# Out:
# Unnamed: 0         Comp.1_neg_unique  Comp.1_pos_unique  Comp.1_unique  \
# BC_CHO                             1                  0              1
# BC_CHO_C15min                      1                  0              1
# BC_CHO_C15max                      0                  0              0
# BC_CHOX                            0                  1              1
# Polyphen                           0                  1              1
# Polyphen_Orich                     0                  0              0
# Polyphen_Opoor                     0                  1              1
# HiUnsatPhen                        0                 69             69
# HiUnsatPhen_Orich                  0                 18             18
# HiUnsatPhen_Opoor                  0                 51             51
# UnsatAliph                         0                  1              1
# UnsatAliph_Orich                   0                  0              0
# ...

# %%
PC7c_sum = PC7c_sum.filter(regex=Comp).reset_index()

# %%
import plotly.express as px
# Construct the graph and style it. Further customize your graph by editing this code.
# See Plotly Documentation for help: https://plotly.com/python/plotly-express/

one=Comp+'_neg_unique'
two = Comp+'_pos_unique'
fig = px.bar(PC7c_sum, x='index', y=[two, one])
fig.update_layout(
    xaxis = dict(
        showgrid=True, 
        rangeslider = dict(
            visible=True, 
            thickness=0.05
        )
    ), 
    yaxis = dict(
        showgrid=True
    ), 
    legend = dict(
        orientation='v'
    ), 
    barmode='group', 
    paper_bgcolor='#FFFFFF'
)
fig.show(renderer="iframe")
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_5.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
